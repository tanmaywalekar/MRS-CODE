# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
#reading file
df = pd.read_csv("gg1.csv",low_memory=False)
df
# Out:
#      S.No.  Sigma_VH  Sigma_VV       C11       C22     Eig_1     Eig_2  \
# 0      1.0  0.023366  0.098682  0.032670  0.008121  0.032819  0.007973
# 1      2.0  0.016498  0.098487  0.027400  0.009674  0.027560  0.009513
# 2      3.0  0.022602  0.124947  0.043431  0.008744  0.043453  0.008722
# 3      4.0  0.021427  0.092403  0.032552  0.009463  0.032929  0.009086
# 4      5.0  0.025875  0.100355  0.029458  0.010976  0.031023  0.009411
# ..     ...       ...       ...       ...       ...       ...       ...
# 124  115.0  0.042406  0.170981  0.062657  0.019711  0.064293  0.018075
# 125  116.0  0.026897  0.099957  0.044775  0.011148  0.044905  0.011017
# 126  117.0  0.019125  0.077247  0.038184  0.010471  0.038325  0.010330
# 127  118.0  0.026304  0.165921  0.041073  0.011584  0.043531  0.009126
# 128  119.0  0.021365  0.145785  0.043597  0.008250  0.044493  0.007355
#
#      Unnamed: 7                  q                 mc             tan Qc  \
# 0           NaN  0.236781463365301  0.617100562421084  0.710989761871101
# 1           NaN  0.167509662200691  0.713047921359478  0.805345771520821
# 2           NaN   0.18089581390182  0.693629511135078  0.787637969175231
# 3           NaN  0.231887889026655  0.623524362740711  0.717858165301146
# 4           NaN  0.257831981166049  0.590037485090766  0.681155674271069
# ..          ...                ...                ...                ...
# 124         NaN  0.248017824171415  0.602541214768179  0.695120659612918
# 125         NaN  0.269086127410855  0.575937169906923   0.66503296332056
# 126         NaN  0.247582246118981  0.603100722394587  0.695738273769787
# 127         NaN  0.158531285901862  0.726323686151552  0.817065399926082
# 128         NaN  0.146551575714345  0.744361128066938  0.832498278575352
#
#                    Qc  Unnamed: 12                 p1                 p2  \
# 0    35.4124372949945          NaN  0.808550281210542  0.191449718789458
# 1    38.8460841300781          NaN  0.856523960679739  0.143476039320261
# 2    38.2253109184365          NaN  0.846814755567539  0.153185244432461
# 3    35.6729844824644          NaN  0.811762181370356  0.188237818629644
# 4    34.2609562907318          NaN  0.795018742545383  0.204981257454617
# ..                ...          ...                ...                ...
# 124  34.8039618579421          NaN   0.80127060738409   0.19872939261591
# 125  33.6252156726913          NaN  0.787968584953462  0.212031415046538
# 126  34.8278134059593          NaN  0.801550361197294  0.198449638802706
# 127  39.2510695919628          NaN  0.863161843075776  0.136838156924224
# 128  39.7773230332597          NaN  0.872180564033469  0.127819435966531
#
#                  log2p1             log2p2  Unnamed: 17                 Hc
# 0    -0.306590601710973   -2.3849625537975          NaN  0.704494327477835
# 1    -0.223434489593472  -2.80111826976425          NaN  0.593270348992453
# 2    -0.239881686667692  -2.70665075852106          NaN  0.617754309897984
# 3    -0.300870966012594  -2.40937158760621          NaN  0.697770523600625
# 4     -0.33093922259283  -2.28643609253926          NaN  0.731779429943017
# ..                  ...                ...          ...                ...
# 124  -0.319638538895737    -2.331122828011          NaN  0.719379589928058
# 125   -0.34378998200178  -2.23765006135287          NaN  0.745347814526741
# 126  -0.319134927511822  -2.33315515838997          NaN  0.718816514870934
# 127  -0.212297004415092  -2.86945751722539          NaN   0.57589795163988
# 128   -0.19730125361363  -2.96782086861376          NaN  0.551427508137158
#
# [129 rows x 19 columns]

# %%
nwdf=df[['Qc','Hc']]
data_types = nwdf.dtypes

print(data_types)
# Out:
# Qc    object
# Hc    object
# dtype: object

# %%
print(nwdf.iloc[:20])
# Out:
#                   Qc                 Hc
# 0   35.4124372949945  0.704494327477835
# 1   38.8460841300781  0.593270348992453
# 2   38.2253109184365  0.617754309897984
# 3   35.6729844824644  0.697770523600625
# 4   34.2609562907318  0.731779429943017
# 5   37.4874852715996  0.643941832493795
# 6    40.135738417164  0.533376059397892
# 7   35.9793533066076   0.68957436908981
# 8   35.9793533066076   0.68957436908981
# 9   35.9793533066076   0.68957436908981
# 10  39.2495681422978  0.575964588976702
# 11  39.3997580390768  0.569212417254688
# 12  40.5156792908337  0.512851427272741
# 13  39.4362795571533  0.567543647026287
# 14  40.4275511843448  0.517748219705668
# 15  40.3567377271791  0.521622002880797
# 16  39.6244910506434  0.558771239501504
# 17  39.2296866800738  0.576845347952962
# 18  38.8355004148647   0.59370874588642
# 19  38.5545020025172   0.60507479831208

# %%
col1='Hc'
col2='Qc'

try:
    # Attempt conversion, ignoring errors (e.g., non-numeric values)
  nwdf.iloc[:, nwdf.columns.get_loc('Hc')] = pd.to_numeric(nwdf['Hc'], errors='coerce')

except:
    pass
try:
    # Attempt conversion, ignoring errors (e.g., non-numeric values)
  nwdf.iloc[:, nwdf.columns.get_loc('Qc')] = pd.to_numeric(nwdf['Qc'], errors='coerce')

except:
    pass

# %%
r1=0
r2=20

xdf=nwdf[r1:r2]

H1=xdf['Hc'].mean()
Q1=xdf['Qc'].mean()
ax = xdf.plot(kind='scatter', x='Hc', y='Qc', title='Date 1', xlim=(0, 1), ylim=(0, 45))



plt.xticks([0, 0.3, 0.5, 0.7, 1.0])
plt.yticks([0, 15, 30, 45])

# Define the boundaries for each quadrant
quadrant_1 = (xdf['Hc'] >= 0) & (xdf['Hc'] <= 0.3) & (xdf['Qc'] >= 0) 
quadrant_2 = (xdf['Hc'] >= 0.3) & (xdf['Hc'] <= 0.5) & (xdf['Qc'] >= 0) 
quadrant_3 = (xdf['Hc'] >= 0.5) & (xdf['Hc'] <= 0.7) & (xdf['Qc'] >= 0) 
quadrant_4 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 30) & (xdf['Qc'] <= 45)
quadrant_5 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 15) & (xdf['Qc'] <= 30)
quadrant_6 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 0) & (xdf['Qc'] <= 15)


# Plot each quadrant with a different color
xdf[quadrant_1].plot(kind='scatter', x='Hc', y='Qc', color='pink', ax=ax)
xdf[quadrant_2].plot(kind='scatter', x='Hc', y='Qc', color='brown', ax=ax)
xdf[quadrant_3].plot(kind='scatter', x='Hc', y='Qc', color='lightgreen', ax=ax)
xdf[quadrant_4].plot(kind='scatter', x='Hc', y='Qc', color='yellow', ax=ax)
xdf[quadrant_5].plot(kind='scatter', x='Hc', y='Qc', color='blue', ax=ax)
xdf[quadrant_6].plot(kind='scatter', x='Hc', y='Qc', color='darkgreen', ax=ax)


plt.grid(True)
# Show the plot
plt.show()

# %%
r1=22
r2=42

xdf=nwdf[r1:r2]
H2=xdf['Hc'].mean()
Q2=xdf['Qc'].mean()

ax = xdf.plot(kind='scatter', x='Hc', y='Qc', title='Date 2', xlim=(0, 1), ylim=(0, 45))



plt.xticks([0, 0.3, 0.5, 0.7, 1.0])
plt.yticks([0, 15, 30, 45])

# Define the boundaries for each quadrant
quadrant_1 = (xdf['Hc'] >= 0) & (xdf['Hc'] <= 0.3) & (xdf['Qc'] >= 0) 
quadrant_2 = (xdf['Hc'] >= 0.3) & (xdf['Hc'] <= 0.5) & (xdf['Qc'] >= 0) 
quadrant_3 = (xdf['Hc'] >= 0.5) & (xdf['Hc'] <= 0.7) & (xdf['Qc'] >= 0) 
quadrant_4 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 30) & (xdf['Qc'] <= 45)
quadrant_5 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 15) & (xdf['Qc'] <= 30)
quadrant_6 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 0) & (xdf['Qc'] <= 15)


# Plot each quadrant with a different color
xdf[quadrant_1].plot(kind='scatter', x='Hc', y='Qc', color='pink', ax=ax)
xdf[quadrant_2].plot(kind='scatter', x='Hc', y='Qc', color='brown', ax=ax)
xdf[quadrant_3].plot(kind='scatter', x='Hc', y='Qc', color='lightgreen', ax=ax)
xdf[quadrant_4].plot(kind='scatter', x='Hc', y='Qc', color='yellow', ax=ax)
xdf[quadrant_5].plot(kind='scatter', x='Hc', y='Qc', color='blue', ax=ax)
xdf[quadrant_6].plot(kind='scatter', x='Hc', y='Qc', color='darkgreen', ax=ax)


plt.grid(True)
# Show the plot
plt.show()

# %%
r1=44
r2=69

xdf=nwdf[r1:r2]
H3=xdf['Hc'].mean()
Q3=xdf['Qc'].mean()


ax = xdf.plot(kind='scatter', x='Hc', y='Qc', title='Date 3', xlim=(0, 1), ylim=(0, 45))



plt.xticks([0, 0.3, 0.5, 0.7, 1.0])
plt.yticks([0, 15, 30, 45])

# Define the boundaries for each quadrant
quadrant_1 = (xdf['Hc'] >= 0) & (xdf['Hc'] <= 0.3) & (xdf['Qc'] >= 0) 
quadrant_2 = (xdf['Hc'] >= 0.3) & (xdf['Hc'] <= 0.5) & (xdf['Qc'] >= 0) 
quadrant_3 = (xdf['Hc'] >= 0.5) & (xdf['Hc'] <= 0.7) & (xdf['Qc'] >= 0) 
quadrant_4 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 30) & (xdf['Qc'] <= 45)
quadrant_5 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 15) & (xdf['Qc'] <= 30)
quadrant_6 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 0) & (xdf['Qc'] <= 15)


# Plot each quadrant with a different color
xdf[quadrant_1].plot(kind='scatter', x='Hc', y='Qc', color='pink', ax=ax)
xdf[quadrant_2].plot(kind='scatter', x='Hc', y='Qc', color='brown', ax=ax)
xdf[quadrant_3].plot(kind='scatter', x='Hc', y='Qc', color='lightgreen', ax=ax)
xdf[quadrant_4].plot(kind='scatter', x='Hc', y='Qc', color='yellow', ax=ax)
xdf[quadrant_5].plot(kind='scatter', x='Hc', y='Qc', color='blue', ax=ax)
xdf[quadrant_6].plot(kind='scatter', x='Hc', y='Qc', color='darkgreen', ax=ax)


plt.grid(True)
# Show the plot
plt.show()

# %%
r1=71
r2=84

xdf=nwdf[r1:r2]

# xdf
H4=xdf['Hc'].mean()
Q4=xdf['Qc'].mean()
ax = xdf.plot(kind='scatter', x='Hc', y='Qc', title='Date 4', xlim=(0, 1), ylim=(0, 45))



plt.xticks([0, 0.3, 0.5, 0.7, 1.0])
plt.yticks([0, 15, 30, 45])

# Define the boundaries for each quadrant
quadrant_1 = (xdf['Hc'] >= 0) & (xdf['Hc'] <= 0.3) & (xdf['Qc'] >= 0) 
quadrant_2 = (xdf['Hc'] >= 0.3) & (xdf['Hc'] <= 0.5) & (xdf['Qc'] >= 0) 
quadrant_3 = (xdf['Hc'] >= 0.5) & (xdf['Hc'] <= 0.7) & (xdf['Qc'] >= 0) 
quadrant_4 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 30) & (xdf['Qc'] <= 45)
quadrant_5 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 15) & (xdf['Qc'] <= 30)
quadrant_6 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 0) & (xdf['Qc'] <= 15)


# Plot each quadrant with a different color
xdf[quadrant_1].plot(kind='scatter', x='Hc', y='Qc', color='pink', ax=ax)
xdf[quadrant_2].plot(kind='scatter', x='Hc', y='Qc', color='brown', ax=ax)
xdf[quadrant_3].plot(kind='scatter', x='Hc', y='Qc', color='lightgreen', ax=ax)
xdf[quadrant_4].plot(kind='scatter', x='Hc', y='Qc', color='yellow', ax=ax)
xdf[quadrant_5].plot(kind='scatter', x='Hc', y='Qc', color='blue', ax=ax)
xdf[quadrant_6].plot(kind='scatter', x='Hc', y='Qc', color='darkgreen', ax=ax)


plt.grid(True)
# Show the plot
plt.show()

# %%
r1=86
r2=109

xdf=nwdf[r1:r2]

# xdf
H5=xdf['Hc'].mean()
Q5=xdf['Qc'].mean()
ax = xdf.plot(kind='scatter', x='Hc', y='Qc', title='Date 5', xlim=(0, 1), ylim=(0, 45))



plt.xticks([0, 0.3, 0.5, 0.7, 1.0])
plt.yticks([0, 15, 30, 45])

# Define the boundaries for each quadrant
quadrant_1 = (xdf['Hc'] >= 0) & (xdf['Hc'] <= 0.3) & (xdf['Qc'] >= 0) 
quadrant_2 = (xdf['Hc'] >= 0.3) & (xdf['Hc'] <= 0.5) & (xdf['Qc'] >= 0) 
quadrant_3 = (xdf['Hc'] >= 0.5) & (xdf['Hc'] <= 0.7) & (xdf['Qc'] >= 0) 
quadrant_4 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 30) & (xdf['Qc'] <= 45)
quadrant_5 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 15) & (xdf['Qc'] <= 30)
quadrant_6 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 0) & (xdf['Qc'] <= 15)


# Plot each quadrant with a different color
xdf[quadrant_1].plot(kind='scatter', x='Hc', y='Qc', color='pink', ax=ax)
xdf[quadrant_2].plot(kind='scatter', x='Hc', y='Qc', color='brown', ax=ax)
xdf[quadrant_3].plot(kind='scatter', x='Hc', y='Qc', color='lightgreen', ax=ax)
xdf[quadrant_4].plot(kind='scatter', x='Hc', y='Qc', color='yellow', ax=ax)
xdf[quadrant_5].plot(kind='scatter', x='Hc', y='Qc', color='blue', ax=ax)
xdf[quadrant_6].plot(kind='scatter', x='Hc', y='Qc', color='darkgreen', ax=ax)


plt.grid(True)
# Show the plot
plt.show()

# %%
r1=111
r2=129

xdf=nwdf[r1:r2]
H6=xdf['Hc'].mean()
Q6=xdf['Qc'].mean()
# xdf
#Scatter plot using pandas.plot()
ax = xdf.plot(kind='scatter', x='Hc', y='Qc', title='Date 6', xlim=(0, 1), ylim=(0, 45))



plt.xticks([0, 0.3, 0.5, 0.7, 1.0])
plt.yticks([0, 15, 30, 45])

# Define the boundaries for each quadrant
quadrant_1 = (xdf['Hc'] >= 0) & (xdf['Hc'] <= 0.3) & (xdf['Qc'] >= 0) 
quadrant_2 = (xdf['Hc'] >= 0.3) & (xdf['Hc'] <= 0.5) & (xdf['Qc'] >= 0) 
quadrant_3 = (xdf['Hc'] >= 0.5) & (xdf['Hc'] <= 0.7) & (xdf['Qc'] >= 0) 
quadrant_4 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 30) & (xdf['Qc'] <= 45)
quadrant_5 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 15) & (xdf['Qc'] <= 30)
quadrant_6 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 0) & (xdf['Qc'] <= 15)


# Plot each quadrant with a different color
xdf[quadrant_1].plot(kind='scatter', x='Hc', y='Qc', color='pink', ax=ax)
xdf[quadrant_2].plot(kind='scatter', x='Hc', y='Qc', color='brown', ax=ax)
xdf[quadrant_3].plot(kind='scatter', x='Hc', y='Qc', color='lightgreen', ax=ax)
xdf[quadrant_4].plot(kind='scatter', x='Hc', y='Qc', color='yellow', ax=ax)
xdf[quadrant_5].plot(kind='scatter', x='Hc', y='Qc', color='blue', ax=ax)
xdf[quadrant_6].plot(kind='scatter', x='Hc', y='Qc', color='darkgreen', ax=ax)


plt.grid(True)
# Show the plot
plt.show()

# %%
avg=[[Q1,H1],[Q2,H2],[Q3,H3],[Q4,H4],[Q5,H5],[Q6,H6]]
dfavg =  pd.DataFrame(avg, columns=['Qav1','Hav1'])
dfavg
# Out:
#         Qav1      Hav1
# 0  38.180441  0.609523
# 1  38.698093  0.587505
# 2  36.501396  0.659313
# 3  31.138846  0.759837
# 4  35.676155  0.686141
# 5  30.134734  0.776313

# %%
dfavg.plot(kind='scatter',x=0, y='Qav1', title='AVG 1 ')
plt.grid(True)
plt.show()

# %%
ranges = [(0, 20), (22, 42),(44, 69), (71, 84), (86, 109), (111, 129)]

# Initialize colors for each dataset
colors = ['blue', 'orange', 'green', 'red', 'purple', 'brown']

# Initialize empty lists to store means
H_means = []
Q_means = []

# Plot each dataset with a different color
for i, (r1, r2) in enumerate(ranges):
    xdf = nwdf[r1:r2]
    H_mean = xdf['Hc'].mean()
    Q_mean = xdf['Qc'].mean()
    H_means.append(H_mean)
    Q_means.append(Q_mean)
    plt.scatter(x='Hc', y='Qc', data=xdf, label=f'Date {i+1}', color=colors[i])

# Plot settings
plt.title('Scatter Plot for Multiple Dates')
plt.xlabel('Hc1')
plt.ylabel('Qc1')
plt.xlim(0, 1)
plt.ylim(0, 45)
plt.legend()
plt.grid(True)
plt.show()

# Print means
for i, (H_mean, Q_mean) in enumerate(zip(H_means, Q_means)):
    print(f"Dataset {i+1}: H_mean={H_mean}, Q_mean={Q_mean}")
# Out:
# Dataset 1: H_mean=0.609522618692144, Q_mean=38.18044054071381
# Dataset 2: H_mean=0.5875047575633608, Q_mean=38.69809297210861
# Dataset 3: H_mean=0.6593133886660871, Q_mean=36.501396074262345
# Dataset 4: H_mean=0.7598372620558848, Q_mean=31.138845505721573
# Dataset 5: H_mean=0.6861411391130888, Q_mean=35.67615492086946
# Dataset 6: H_mean=0.7763128024148573, Q_mean=30.13473354199058

# %%
import matplotlib.pyplot as plt

# Define a function to generate the plot for a given range (r1, r2)
def generate_plot(r1, r2, fig, ax):
  xdf = nwdf[r1:r2]

  H1 = xdf['Hc'].mean()
  Q1 = xdf['Qc'].mean()

  # Option 1: Using linewidths (adjust value as needed)
  # ax.scatter(xdf['Hc'], xdf['Qc'], markeredgewidth=0, linewidths=0.1)

  # Option 2: Using markers without edges
  ax.scatter(xdf['Hc'], xdf['Qc'], marker='.')  # Point marker (no edge)

  ax.set_xlim(0, 1)
  ax.set_ylim(0, 45)
  ax.set_xticks([0, 0.3, 0.5, 0.7, 1.0])
  ax.set_yticks([0, 15, 30, 45])

  # Define quadrant boundaries (adjust as needed)
  quadrant_1 = (xdf['Hc'] >= 0) & (xdf['Hc'] <= 0.3) & (xdf['Qc'] >= 0)
  quadrant_2 = (xdf['Hc'] >= 0.3) & (xdf['Hc'] <= 0.5) & (xdf['Qc'] >= 0)
  quadrant_3 = (xdf['Hc'] >= 0.5) & (xdf['Hc'] <= 0.7) & (xdf['Qc'] >= 0)
  quadrant_4 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 30) & (xdf['Qc'] <= 45)
  quadrant_5 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 15) & (xdf['Qc'] <= 30)
  quadrant_6 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] <= 15)

  # Plot each quadrant with a different color
  xdf[quadrant_1].plot(kind='scatter', x='Hc', y='Qc', color='pink', ax=ax)
  xdf[quadrant_2].plot(kind='scatter', x='Hc', y='Qc', color='brown', ax=ax)
  xdf[quadrant_3].plot(kind='scatter', x='Hc', y='Qc', color='lightgreen', ax=ax)
  xdf[quadrant_4].plot(kind='scatter', x='Hc', y='Qc', color='yellow', ax=ax)
  xdf[quadrant_5].plot(kind='scatter', x='Hc', y='Qc', color='blue', ax=ax)
  xdf[quadrant_6].plot(kind='scatter', x='Hc', y='Qc', color='darkgreen', ax=ax)

  ax.grid(True)

# List of ranges for generating plots
ranges = [(0, 20), (22, 42), (44, 69), (71, 84), (86, 109), (111, 129)]
dates = ["15-03-2023", "28-03-2023", "09-04-2023", "21-04-2023", "03-05-2023", "15-05-2023"]
# Create a figure with a 2x3 grid layout (adjust if needed for the number of plots)
fig, axes = plt.subplots(2, 3, figsize=(12, 6))

# Generate and plot graps on each subplot
for i, (r1, r2) in enumerate(ranges):
  ax = axes.flat[i]
  date_to_display = dates[i]    
  ax.set_title(f" {date_to_display}")
  
  generate_plot(r1, r2, fig, ax)
  ax.set_xlabel(r'H$_c$')
  ax.set_ylabel(r'$\theta_c$')

# Adjust layout and spacing (optional)
# fig.suptitle("Multiple Scatter Plots with Quadrants (Ranges from your list)")
plt.tight_layout()

# Save the image
plt.savefig("multiple_scatter_plots_custom_ranges_no_outline.png")

# Optionally, display the image (if running the script directly)
plt.show()
