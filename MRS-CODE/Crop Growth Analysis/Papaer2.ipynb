# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
#reading file
df = pd.read_csv("gg2.csv",low_memory=False)
df
# Out:
#      S.No.  Sigma_VH  Sigma_VV       C11       C22     Eig_1     Eig_2  \
# 0      1.0  0.023366  0.098682  0.032670  0.008121  0.032819  0.007973
# 1      2.0  0.016498  0.098487  0.027400  0.009674  0.027560  0.009513
# 2      3.0  0.022602  0.124947  0.043431  0.008744  0.043453  0.008722
# 3      4.0  0.021427  0.092403  0.032552  0.009463  0.032929  0.009086
# 4      5.0  0.025875  0.100355  0.029458  0.010976  0.031023  0.009411
# ..     ...       ...       ...       ...       ...       ...       ...
# 124  115.0  0.042406  0.170981  0.062657  0.019711  0.064293  0.018075
# 125  116.0  0.026897  0.099957  0.044775  0.011148  0.044905  0.011017
# 126  117.0  0.019125  0.077247  0.038184  0.010471  0.038325  0.010330
# 127  118.0  0.026304  0.165921  0.041073  0.011584  0.043531  0.009126
# 128  119.0  0.021365  0.145785  0.043597  0.008250  0.044493  0.007355
#
#      Unnamed: 7  Unnamed: 8        w1  ...              tanQc Unnamed: 14  \
# 0           NaN         NaN  0.164171  ...  0.705955438683536         NaN
# 1           NaN         NaN  0.153447  ...  0.716931389927452         NaN
# 2           NaN         NaN  0.211831  ...  0.776581926901823         NaN
# 3           NaN         NaN  0.157884  ...  0.687763076479586         NaN
# 4           NaN         NaN  0.160837  ...  0.638251015144888         NaN
# ..          ...         ...       ...  ...                ...         ...
# 124         NaN         NaN  0.297931  ...  0.664925044224568         NaN
# 125         NaN         NaN  0.189637  ...  0.679893421002634         NaN
# 126         NaN         NaN  0.153756  ...  0.678522311572056         NaN
# 127         NaN         NaN  0.250525  ...  0.778582243235522         NaN
# 128         NaN         NaN  0.233874  ...   0.81765497241914         NaN
#
#                    Qc Unnamed: 16                 p1                 p2  \
# 0    35.2203877653142         NaN  0.806219903240669  0.193780096759331
# 1    35.6379267901108         NaN  0.811326561646187  0.188673438353813
# 2    37.8322674125503         NaN  0.840935602481379  0.159064397518622
# 3    34.5187570941115         NaN  0.797959370896604  0.202040629103396
# 4    32.5480959104944         NaN  0.776622188962041  0.223377811037959
# ..                ...         ...                ...                ...
# 124  33.6209282498173         NaN  0.787921972463487  0.212078027536513
# 125  34.2115262370834         NaN  0.794460447284753  0.205539552715247
# 126  34.1577675756989         NaN  0.793855249215014  0.206144750784986
# 127  37.9036916145205         NaN  0.841989318842411  0.158010681157589
# 128  39.2713204570454         NaN  0.863500459496105  0.136499540503895
#
#                   logp1              logp2 Unnamed: 21                 Hc
# 0    -0.310754695285357  -2.36750769637993         NaN  0.709312490847508
# 1    -0.301645373984513  -2.40603676178734         NaN  0.698688132763426
# 2    -0.249932769481814  -2.65231713332967         NaN  0.632066590925429
# 3    -0.325612803199389   -2.3072826558113         NaN  0.725990626896335
# 4    -0.364715167645883   -2.1624422102988         NaN  0.766287499277436
# ..                  ...                ...         ...                ...
# 124  -0.343875327532702  -2.23733293750865         NaN  0.745436082680402
# 125  -0.331952699009684  -2.28251205127035         NaN  0.732869795817883
# 126   -0.33305212313317  -2.27827036959584         NaN  0.734048653772624
# 127  -0.248126162962467  -2.66190601033154         NaN  0.629529160809715
# 128  -0.211731149428964  -2.87303200025409         NaN  0.574997492709217
#
# [129 rows x 23 columns]

# %%
nwdf=df[['Qc','Hc']]

# %%
print(nwdf.iloc[:20])
# Out:
#                   Qc                 Hc
# 0   35.2203877653142  0.709312490847508
# 1   35.6379267901108  0.698688132763426
# 2   37.8322674125503  0.632066590925429
# 3   34.5187570941115  0.725990626896335
# 4   32.5480959104944  0.766287499277436
# 5   36.2583665683371   0.68182150582607
# 6   39.3852475686137  0.569872488524635
# 7   35.6643516698291    0.6979968593895
# 8   35.7287560549638  0.696302307159484
# 9   35.4464582065808  0.703628780253323
# 10  38.4199324106536  0.610338055080239
# 11  39.4813884219994  0.565467681766406
# 12  40.2405501042954  0.527863677846021
# 13   39.288025412974  0.574252333481354
# 14   39.673078697276  0.556458452133016
# 15  38.6995439930798  0.599272994130712
# 16  38.6419279104657  0.601594007892074
# 17  39.0972415496026  0.582636919326788
# 18   38.882013496422  0.591776351690233
# 19  38.3903875718567   0.61147858818953

# %%
col1='Hc'
col2='Qc'


try:
    # Attempt conversion, ignoring errors (e.g., non-numeric values)
  nwdf.iloc[:, nwdf.columns.get_loc('Hc')] = pd.to_numeric(nwdf['Hc'], errors='coerce')

except:
    pass
try:
    # Attempt conversion, ignoring errors (e.g., non-numeric values)
  nwdf.iloc[:, nwdf.columns.get_loc('Qc')] = pd.to_numeric(nwdf['Qc'], errors='coerce')

except:
    pass

# %%
r1=0
r2=20

xdf=nwdf[r1:r2]

H1=xdf['Hc'].mean()
Q1=xdf['Qc'].mean()
ax = xdf.plot(kind='scatter', x='Hc', y='Qc', title='Date 1', xlim=(0, 1), ylim=(0, 45))



plt.xticks([0, 0.3, 0.5, 0.7, 1.0])
plt.yticks([0, 15, 30, 45])

# Define the boundaries for each quadrant
quadrant_1 = (xdf['Hc'] >= 0) & (xdf['Hc'] <= 0.3) & (xdf['Qc'] >= 0) 
quadrant_2 = (xdf['Hc'] >= 0.3) & (xdf['Hc'] <= 0.5) & (xdf['Qc'] >= 0) 
quadrant_3 = (xdf['Hc'] >= 0.5) & (xdf['Hc'] <= 0.7) & (xdf['Qc'] >= 0) 
quadrant_4 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 30) & (xdf['Qc'] <= 45)
quadrant_5 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 15) & (xdf['Qc'] <= 30)
quadrant_6 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 0) & (xdf['Qc'] <= 15)


# Plot each quadrant with a different color
xdf[quadrant_1].plot(kind='scatter', x='Hc', y='Qc', color='pink', ax=ax)
xdf[quadrant_2].plot(kind='scatter', x='Hc', y='Qc', color='brown', ax=ax)
xdf[quadrant_3].plot(kind='scatter', x='Hc', y='Qc', color='lightgreen', ax=ax)
xdf[quadrant_4].plot(kind='scatter', x='Hc', y='Qc', color='yellow', ax=ax)
xdf[quadrant_5].plot(kind='scatter', x='Hc', y='Qc', color='blue', ax=ax)
xdf[quadrant_6].plot(kind='scatter', x='Hc', y='Qc', color='darkgreen', ax=ax)


plt.grid(True)
# Show the plot
plt.show()

# %%
r1=22
r2=42

xdf=nwdf[r1:r2]

H2=xdf['Hc'].mean()
Q2=xdf['Qc'].mean()
ax = xdf.plot(kind='scatter', x='Hc', y='Qc', title='Date 2', xlim=(0, 1), ylim=(0, 45))



plt.xticks([0, 0.3, 0.5, 0.7, 1.0])
plt.yticks([0, 15, 30, 45])

# Define the boundaries for each quadrant
quadrant_1 = (xdf['Hc'] >= 0) & (xdf['Hc'] <= 0.3) & (xdf['Qc'] >= 0) 
quadrant_2 = (xdf['Hc'] >= 0.3) & (xdf['Hc'] <= 0.5) & (xdf['Qc'] >= 0) 
quadrant_3 = (xdf['Hc'] >= 0.5) & (xdf['Hc'] <= 0.7) & (xdf['Qc'] >= 0) 
quadrant_4 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 30) & (xdf['Qc'] <= 45)
quadrant_5 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 15) & (xdf['Qc'] <= 30)
quadrant_6 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 0) & (xdf['Qc'] <= 15)


# Plot each quadrant with a different color
xdf[quadrant_1].plot(kind='scatter', x='Hc', y='Qc', color='pink', ax=ax)
xdf[quadrant_2].plot(kind='scatter', x='Hc', y='Qc', color='brown', ax=ax)
xdf[quadrant_3].plot(kind='scatter', x='Hc', y='Qc', color='lightgreen', ax=ax)
xdf[quadrant_4].plot(kind='scatter', x='Hc', y='Qc', color='yellow', ax=ax)
xdf[quadrant_5].plot(kind='scatter', x='Hc', y='Qc', color='blue', ax=ax)
xdf[quadrant_6].plot(kind='scatter', x='Hc', y='Qc', color='darkgreen', ax=ax)


plt.grid(True)
# Show the plot
plt.show()

# %%
r1=44
r2=69

xdf=nwdf[r1:r2]


H3=xdf['Hc'].mean()
Q3=xdf['Qc'].mean()
ax = xdf.plot(kind='scatter', x='Hc', y='Qc', title='Date 3', xlim=(0, 1), ylim=(0, 45))



plt.xticks([0, 0.3, 0.5, 0.7, 1.0])
plt.yticks([0, 15, 30, 45])

# Define the boundaries for each quadrant
quadrant_1 = (xdf['Hc'] >= 0) & (xdf['Hc'] <= 0.3) & (xdf['Qc'] >= 0) 
quadrant_2 = (xdf['Hc'] >= 0.3) & (xdf['Hc'] <= 0.5) & (xdf['Qc'] >= 0) 
quadrant_3 = (xdf['Hc'] >= 0.5) & (xdf['Hc'] <= 0.7) & (xdf['Qc'] >= 0) 
quadrant_4 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 30) & (xdf['Qc'] <= 45)
quadrant_5 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 15) & (xdf['Qc'] <= 30)
quadrant_6 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 0) & (xdf['Qc'] <= 15)


# Plot each quadrant with a different color
xdf[quadrant_1].plot(kind='scatter', x='Hc', y='Qc', color='pink', ax=ax)
xdf[quadrant_2].plot(kind='scatter', x='Hc', y='Qc', color='brown', ax=ax)
xdf[quadrant_3].plot(kind='scatter', x='Hc', y='Qc', color='lightgreen', ax=ax)
xdf[quadrant_4].plot(kind='scatter', x='Hc', y='Qc', color='yellow', ax=ax)
xdf[quadrant_5].plot(kind='scatter', x='Hc', y='Qc', color='blue', ax=ax)
xdf[quadrant_6].plot(kind='scatter', x='Hc', y='Qc', color='darkgreen', ax=ax)


plt.grid(True)
# Show the plot
plt.show()

# %%
r1=71
r2=84

xdf=nwdf[r1:r2]

# xdf
H4=xdf['Hc'].mean()
Q4=xdf['Qc'].mean()
ax = xdf.plot(kind='scatter', x='Hc', y='Qc', title='Date 4', xlim=(0, 1), ylim=(0, 45))



plt.xticks([0, 0.3, 0.5, 0.7, 1.0])
plt.yticks([0, 15, 30, 45])

# Define the boundaries for each quadrant
quadrant_1 = (xdf['Hc'] >= 0) & (xdf['Hc'] <= 0.3) & (xdf['Qc'] >= 0) 
quadrant_2 = (xdf['Hc'] >= 0.3) & (xdf['Hc'] <= 0.5) & (xdf['Qc'] >= 0) 
quadrant_3 = (xdf['Hc'] >= 0.5) & (xdf['Hc'] <= 0.7) & (xdf['Qc'] >= 0) 
quadrant_4 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 30) & (xdf['Qc'] <= 45)
quadrant_5 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 15) & (xdf['Qc'] <= 30)
quadrant_6 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 0) & (xdf['Qc'] <= 15)


# Plot each quadrant with a different color
xdf[quadrant_1].plot(kind='scatter', x='Hc', y='Qc', color='pink', ax=ax)
xdf[quadrant_2].plot(kind='scatter', x='Hc', y='Qc', color='brown', ax=ax)
xdf[quadrant_3].plot(kind='scatter', x='Hc', y='Qc', color='lightgreen', ax=ax)
xdf[quadrant_4].plot(kind='scatter', x='Hc', y='Qc', color='yellow', ax=ax)
xdf[quadrant_5].plot(kind='scatter', x='Hc', y='Qc', color='blue', ax=ax)
xdf[quadrant_6].plot(kind='scatter', x='Hc', y='Qc', color='darkgreen', ax=ax)


plt.grid(True)
# Show the plot
plt.show()

# %%
r1=86
r2=109

xdf=nwdf[r1:r2]

# xdf
H5=xdf['Hc'].mean()
Q5=xdf['Qc'].mean()
ax = xdf.plot(kind='scatter', x='Hc', y='Qc', title='Date 5', xlim=(0, 1), ylim=(0, 45))



plt.xticks([0, 0.3, 0.5, 0.7, 1.0])
plt.yticks([0, 15, 30, 45])

# Define the boundaries for each quadrant
quadrant_1 = (xdf['Hc'] >= 0) & (xdf['Hc'] <= 0.3) & (xdf['Qc'] >= 0) 
quadrant_2 = (xdf['Hc'] >= 0.3) & (xdf['Hc'] <= 0.5) & (xdf['Qc'] >= 0) 
quadrant_3 = (xdf['Hc'] >= 0.5) & (xdf['Hc'] <= 0.7) & (xdf['Qc'] >= 0) 
quadrant_4 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 30) & (xdf['Qc'] <= 45)
quadrant_5 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 15) & (xdf['Qc'] <= 30)
quadrant_6 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 0) & (xdf['Qc'] <= 15)


# Plot each quadrant with a different color
xdf[quadrant_1].plot(kind='scatter', x='Hc', y='Qc', color='pink', ax=ax)
xdf[quadrant_2].plot(kind='scatter', x='Hc', y='Qc', color='brown', ax=ax)
xdf[quadrant_3].plot(kind='scatter', x='Hc', y='Qc', color='lightgreen', ax=ax)
xdf[quadrant_4].plot(kind='scatter', x='Hc', y='Qc', color='yellow', ax=ax)
xdf[quadrant_5].plot(kind='scatter', x='Hc', y='Qc', color='blue', ax=ax)
xdf[quadrant_6].plot(kind='scatter', x='Hc', y='Qc', color='darkgreen', ax=ax)


plt.grid(True)
# Show the plot
plt.show()

# %%
r1=111
r2=129

xdf=nwdf[r1:r2]

# xdf
H6=xdf['Hc'].mean()
Q6=xdf['Qc'].mean()
#Scatter plot using pandas.plot()
ax = xdf.plot(kind='scatter', x='Hc', y='Qc', title='Date 6', xlim=(0, 1), ylim=(0, 45))



plt.xticks([0, 0.3, 0.5, 0.7, 1.0])
plt.yticks([0, 15, 30, 45])

# Define the boundaries for each quadrant
quadrant_1 = (xdf['Hc'] >= 0) & (xdf['Hc'] <= 0.3) & (xdf['Qc'] >= 0) 
quadrant_2 = (xdf['Hc'] >= 0.3) & (xdf['Hc'] <= 0.5) & (xdf['Qc'] >= 0) 
quadrant_3 = (xdf['Hc'] >= 0.5) & (xdf['Hc'] <= 0.7) & (xdf['Qc'] >= 0) 
quadrant_4 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 30) & (xdf['Qc'] <= 45)
quadrant_5 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 15) & (xdf['Qc'] <= 30)
quadrant_6 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 0) & (xdf['Qc'] <= 15)


# Plot each quadrant with a different color
xdf[quadrant_1].plot(kind='scatter', x='Hc', y='Qc', color='pink', ax=ax)
xdf[quadrant_2].plot(kind='scatter', x='Hc', y='Qc', color='brown', ax=ax)
xdf[quadrant_3].plot(kind='scatter', x='Hc', y='Qc', color='lightgreen', ax=ax)
xdf[quadrant_4].plot(kind='scatter', x='Hc', y='Qc', color='yellow', ax=ax)
xdf[quadrant_5].plot(kind='scatter', x='Hc', y='Qc', color='blue', ax=ax)
xdf[quadrant_6].plot(kind='scatter', x='Hc', y='Qc', color='darkgreen', ax=ax)


plt.grid(True)
# Show the plot
plt.show()

# %%
# avg2=[[Q1,H1],[Q2,H2],[Q3,H3],[Q4,H4],[Q5,H5],[Q6,H6]]
# dfavg2 = pd.DataFrame(avg2, columns=['Qav2','Hav2'])
# avg1=[[38.180441,0.609523],[38.698093,0.587505],[36.501396,0.659313],[31.138846,0.759837],[35.676155,0.686141],[30.134734,0.776313]]
# dfavg1 = pd.DataFrame(avg1, columns=['Qav1','Hav1'])

AvQ=[[Q1,38.180441],[Q2,38.698093],[Q3,36.501396],[Q4,31.138846],[Q5,35.67615],[Q6,30.134734]]
# dfQ = pd.DataFrame(AvQ, columns=['Q1avg','Q2avg'])
AvH=[[H1,0.609523],[H2,0.587505],[H3,0.659313],[H4,0.759837],[H5,0.686141],[H6,0.776313]]
# dfH = pd.DataFrame(AvH, columns=['H1avg','H2avg'])

# %%
# dfQ.plot(kind='line')
# plt.xlabel('Date')
# plt.ylabel('Q')
# plt.title('Q1 vs Q2')
# plt.show()

# %%
# dfH.plot(kind='line')
# plt.xlabel('Date')
# plt.ylabel('H')
# plt.title('H1 vs H2')
# plt.show()

# %%
# import matplotlib.pyplot as plt

# # Define a function to generate the plot for a given range (r1, r2)
# def generate_plot(r1, r2, fig, ax):
#   xdf = nwdf[r1:r2]

#   H1 = xdf['Hc'].mean()
#   Q1 = xdf['Qc'].mean()

#   # Option 1: Using linewidths (adjust value as needed)
#   # ax.scatter(xdf['Hc'], xdf['Qc'], markeredgewidth=0, linewidths=0.1)

#   # Option 2: Using markers without edges
#   ax.scatter(xdf['Hc'], xdf['Qc'], marker='.')  # Point marker (no edge)

#   ax.set_xlim(0, 1)
#   ax.set_ylim(0, 45)
#   ax.set_xticks([0, 0.3, 0.5, 0.7, 1.0])
#   ax.set_yticks([0, 15, 30, 45])

#   # Define quadrant boundaries (adjust as needed)
#   quadrant_1 = (xdf['Hc'] >= 0) & (xdf['Hc'] <= 0.3) & (xdf['Qc'] >= 0)
#   quadrant_2 = (xdf['Hc'] >= 0.3) & (xdf['Hc'] <= 0.5) & (xdf['Qc'] >= 0)
#   quadrant_3 = (xdf['Hc'] >= 0.5) & (xdf['Hc'] <= 0.7) & (xdf['Qc'] >= 0)
#   quadrant_4 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 30) & (xdf['Qc'] <= 45)
#   quadrant_5 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] >= 15) & (xdf['Qc'] <= 30)
#   quadrant_6 = (xdf['Hc'] >= 0.7) & (xdf['Hc'] <= 1) & (xdf['Qc'] <= 15)

#   # Plot each quadrant with a different color
#   xdf[quadrant_1].plot(kind='scatter', x='Hc', y='Qc', color='pink', ax=ax)
#   xdf[quadrant_2].plot(kind='scatter', x='Hc', y='Qc', color='brown', ax=ax)
#   xdf[quadrant_3].plot(kind='scatter', x='Hc', y='Qc', color='lightgreen', ax=ax)
#   xdf[quadrant_4].plot(kind='scatter', x='Hc', y='Qc', color='yellow', ax=ax)
#   xdf[quadrant_5].plot(kind='scatter', x='Hc', y='Qc', color='blue', ax=ax)
#   xdf[quadrant_6].plot(kind='scatter', x='Hc', y='Qc', color='darkgreen', ax=ax)

#   ax.grid(True)

# # List of ranges for generating plots
# ranges = [(0, 20), (22, 42), (44, 69), (71, 84), (86, 109), (111, 129)]
# dates = ["15-03-2023", "28-03-2023", "09-04-2023", "21-04-2023", "03-05-2023", "15-05-2023"]
# # Create a figure with a 2x3 grid layout (adjust if needed for the number of plots)
# fig, axes = plt.subplots(2, 3, figsize=(12, 6))

# # Generate and plot graps on each subplot
# for i, (r1, r2) in enumerate(ranges):
#   ax = axes.flat[i]
#   date_to_display = dates[i]    
#   ax.set_title(f" {date_to_display}")
  
#   generate_plot(r1, r2, fig, ax)
#   ax.set_xlabel(r'H$_c$')
#   ax.set_ylabel(r'$\theta_c$')

# # Adjust layout and spacing (optional)
# # fig.suptitle("Multiple Scatter Plots with Quadrants (Ranges from your list)")
# plt.tight_layout()

# # Save the image
# plt.savefig("multiple_scatter_plots_custom_ranges_no_outline.png")

# # Optionally, display the image (if running the script directly)
# plt.show()

# %%
import matplotlib.pyplot as plt

# Your data
AvH = [[H1,0.609523],[H2,0.587505],[H3,0.659313],[H4,0.759837],[H5,0.686141],[H6,0.776313]]
dates = ["15-03-2023", "28-03-2023", "09-04-2023", "21-04-2023", "03-05-2023", "15-05-2023"]

# Unpack data for easier plotting
method1_values, method2_values = zip(*AvH)  # zip unpacks corresponding elements from lists

# Create the plot

plt.plot(dates, method1_values, label=r'$\overline{H}_{c1}$')
plt.plot(dates, method2_values, label=r'$\overline{H}_{c2}$')

# Add labels and title
plt.xlabel("Dates")
plt.ylabel(r'$H_c$')
# plt.title("Comparison of Estimation Methods")

# Add legend
plt.legend()

# Rotate x-axis labels for better readability if many dates
plt.xticks(rotation=45)  # Optional: rotate x-axis labels

# Show the plot
#plt.grid(True)  # Optional: add grid lines
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

# Your data
AvQ = [[Q1,38.180441],[Q2,38.698093],[Q3,36.501396],[Q4,31.138846],[Q5,35.67615],[Q6,30.134734]]

dates = ["15-03-2023", "28-03-2023", "09-04-2023", "21-04-2023", "03-05-2023", "15-05-2023"]
# Unpack data for easier plotting
method1_values, method2_values = zip(*AvQ)  # zip unpacks corresponding elements from lists

# Create the plot
plt.plot(dates, method1_values, label=r'$\overline{\theta}_{c1}$')
plt.plot(dates, method2_values, label=r'$\overline{\theta}_{c2}$')

# Add labels and title
plt.xlabel("Dates")
plt.ylabel(r'${\theta}_{c}$')
# plt.title("Comparison of Estimation Methods")

# Add legend
plt.legend()

# Rotate x-axis labels for better readability if many dates
plt.xticks(rotation=45)  # Optional: rotate x-axis labels

# Show the plot
#plt.grid(True)  # Optional: add grid lines
plt.tight_layout()
plt.show()
